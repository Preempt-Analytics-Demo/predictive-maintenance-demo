# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\actor\Downloads\runs.csv")
df.head()
# Out:
#             Start Time Duration                            Run ID  \
# 0  2026-05-21 11:28:38    19.5s  7b72030aaded4f7d82e5e0ebbfbf7cf5
# 1  2026-05-21 11:28:10    48.8s  3f1ab128071743cca7f3aed22e05bfe0
# 2  2026-05-21 11:05:23    49.2s  efe6036f462a4cc0ace730986e35e200
# 3  2026-05-21 11:00:40    26.0s  9c86cf6c1e8140abbcabf1acd3b41199
#
#                  Name Source Type           Source Name            User  \
# 0       bouncy-ray-96       LOCAL  modeling_pipeline.py  envelopingcode
# 1     useful-fawn-282       LOCAL  modeling_pipeline.py        undorigo
# 2    bustling-ray-595       LOCAL  modeling_pipeline.py        undorigo
# 3  unleashed-midge-39       LOCAL  modeling_pipeline.py  envelopingcode
#
#      Status boosting_type  class_weight  ...   f1_test f1_train  \
# 0  FINISHED          gbdt           NaN  ...  0.861538        1
# 1  FINISHED          gbdt           NaN  ...  0.647001        1
# 2  FINISHED          gbdt           NaN  ...  0.647001        1
# ...
